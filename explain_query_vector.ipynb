# %%
import psycopg2
import json

# %%
request = {
    "entities": {
        "capabilities": [
            "Apache Hadoop",
            "Spark",
            "AWS",
            "arquitecturas de datos escalables",
            "análisis de datos en tiempo real",
            "automatización de procesos",
            "Docker",
            "Kubernetes",
            "Java"
        ],
        "role": "Ingeniero de datos"
    },
    "input_token": 90,
    "output_token": 42,
    "tokens": 132
}

# %%
import os
import psycopg2
from psycopg2 import DatabaseError
from dotenv import load_dotenv

#cargar las variables de entorno
load_dotenv()

#Crear conexion con PostgreSQL
def get_db_connection():
    try:
        connection = psycopg2.connect(
            host=os.getenv('PGSQL_HOST'),
            user=os.getenv('PGSQL_USER'),
            password=os.getenv('PGSQL_PASSWORD'),
            dbname=os.getenv('PGSQL_DATABASE'),
            port=os.getenv('PGSQL_PORT')
        )
        return connection
    except DatabaseError as ex:
        raise ex

# %%
from psycopg2.extras import RealDictCursor

def buscar_candidatos_postgre(rol, capabilities):
    # Formatear la búsqueda para usar en to_tsquery
    
    busqueda_capabilities = ' | '.join(
            [f"'{capability.strip()}'" if ' ' in capability else capability.strip() for capability in capabilities]
        )

    if busqueda_capabilities.startswith(" | "):
        busqueda_capabilities = busqueda_capabilities[3:]
    if busqueda_capabilities.endswith(" | "):
        busqueda_capabilities = busqueda_capabilities[:-3]
        

    if isinstance(rol, str):
        busqueda_rol = rol.strip()  # Eliminar espacios innecesarios
        busqueda_rol = ' & '.join(busqueda_rol.split())  # Reemplazar espacios por " & " para to_tsquery
    else:
        raise ValueError("El parámetro 'rol' debe ser una cadena.")

    print(busqueda_capabilities, busqueda_rol)
    
    consulta = """
    SET enable_nestloop = off; 
    
    EXPLAIN ANALYZE
WITH filtered_skills AS (
    SELECT id, description
    FROM recruitment.skills
    WHERE description IN ('Apache Hadoop', 'Spark', 'AWS', 'Docker', 'Kubernetes', 'Java', 'Python', 'SQL')
),
filtered_job_profile AS (
    SELECT jobs.id AS job_id, jobs.name AS job_name, level_of_exp.name AS level_name, jobs.profile_type_id AS profile_type_id, profiles_type.description AS profile_type_description
    FROM recruitment.job AS jobs
    INNER JOIN recruitment.levelofexp AS level_of_exp 
        ON level_of_exp.id = jobs.levelofexperience_id
    INNER JOIN recruitment.profiletype AS profiles_type
        ON jobs.profile_type_id = profiles_type.id
    WHERE to_tsvector('spanish', jobs.name || ' ' || profiles_type.description || ' ' || level_of_exp.name) 
        @@ to_tsquery('spanish', 'Ingeniero & de & datos')
)
SELECT 
    a_p.id AS applicant_profile_id,
    u.name AS user_name, 
    job.job_name,
    job.level_name AS level_of_exp, 
    job.profile_type_description AS profile_type,
    ARRAY_AGG(skills.description) AS skills,
	workexperience.description 
FROM 
    recruitment.user AS u
INNER JOIN 
    recruitment.applicant_profile AS a_p ON u.user_id = a_p.user_id
INNER JOIN 
    recruitment.applicantprofile_skill AS a_p_skill ON a_p_skill.applicant_profile_id = a_p.id
INNER JOIN 
    filtered_skills AS skills ON skills.id = a_p_skill.skill_id
INNER JOIN 
    recruitment.application AS application ON u.user_id = application.user_id
INNER JOIN 
    filtered_job_profile AS job ON job.job_id = application.job_id
INNER JOIN 
	recruitment.workexperience AS workexperience on workexperience.applicantprofile_id = a_p.id
GROUP BY 
    a_p.id, u.name, job.job_name, job.job_id, job.level_name, job.profile_type_description, workexperience.description; 

    """
    resultados = []
    try:
        conn = get_db_connection()  # Obtén la conexión a la base de datos
        with conn.cursor(cursor_factory=psycopg2.extras.DictCursor) as cur:
            # Ejecutar la consulta con el término de búsqueda seguro
            cur.execute(consulta, (busqueda_capabilities,busqueda_rol))
            resultados = cur.fetchall()

        conn.close()
    except Exception as e:
        print(f"Error al consultar PostgreSQL: {e}")
    
    # Convertir los resultados en una lista de diccionarios
    # return json.dumps([dict(row) for row in resultados], default=str)
    return [dict(row) for row in resultados]

# %%
data = request
role = data["entities"]["role"]
capabilities = data["entities"]["capabilities"]

# Llamar a la función de búsqueda con el término combinado
aplicantes_filtrados = buscar_candidatos_postgre(role, capabilities)
# Out:
# 'Apache Hadoop' | Spark | AWS | 'arquitecturas de datos escalables' | 'análisis de datos en tiempo real' | 'automatización de procesos' | Docker | Kubernetes | Java Ingeniero & de & datos

# %%
aplicantes_filtrados
# Out:
# [{'QUERY PLAN': 'GroupAggregate  (cost=29561.12..29869.94 rows=2145 width=200) (actual time=633.028..670.139 rows=35605 loops=1)'},
#  {'QUERY PLAN': '  Group Key: a_p.id, u.name, jobs.id, level_of_exp.name, profiles_type.description, workexperience.description'},
#  {'QUERY PLAN': '  ->  Gather Merge  (cost=29561.12..29805.59 rows=2145 width=178) (actual time=633.015..651.407 rows=45215 loops=1)'},
#  {'QUERY PLAN': '        Workers Planned: 1'},
#  {'QUERY PLAN': '        Workers Launched: 1'},
#  {'QUERY PLAN': '        ->  Sort  (cost=28561.11..28564.26 rows=1262 width=178) (actual time=626.875..628.774 rows=22608 loops=2)'},
#  {'QUERY PLAN': '              Sort Key: a_p.id, u.name, jobs.id, level_of_exp.name, profiles_type.description, workexperience.description'},
#  {'QUERY PLAN': '              Sort Method: external merge  Disk: 4096kB'},
#  {'QUERY PLAN': '              Worker 0:  Sort Method: external merge  Disk: 4136kB'},
#  {'QUERY PLAN': '              ->  Parallel Hash Join  (cost=25177.76..28496.11 rows=1262 width=178) (actual time=575.553..605.282 rows=22608 loops=2)'},
#  {'QUERY PLAN': '                    Hash Cond: (workexperience.applicantprofile_id = a_p_skill.applicant_profile_id)'},
#  {'QUERY PLAN': '                    ->  Parallel Seq Scan on workexperience  (cost=0.00..3065.54 rows=65454 width=97) (actual time=0.003..16.799 rows=55636 loops=2)'},
#  {'QUERY PLAN': '                    ->  Parallel Hash  (cost=25161.98..25161.98 rows=1262 width=89) (actual time=575.218..575.231 rows=22608 loops=2)'},
#  {'QUERY PLAN': '                          Buckets: 65536 (originally 4096)  Batches: 1 (originally 1)  Memory Usage: 6816kB'},
#  {'QUERY PLAN': '                          ->  Parallel Hash Join  (cost=22810.74..25161.98 rows=1262 width=89) (actual time=549.241..567.264 rows=22608 loops=2)'},
#  {'QUERY PLAN': '                                Hash Cond: ((u.user_id)::text = (a_p.user_id)::text)'},
#  {'QUERY PLAN': '                                ->  Parallel Seq Scan on "user" u  (cost=0.00..2100.54 rows=65454 width=51) (actual time=0.003..5.408 rows=55636 loops=2)'},
#  {'QUERY PLAN': '                                ->  Parallel Hash  (cost=22799.56..22799.56 rows=894 width=149) (actual time=549.158..549.170 rows=22608 loops=2)'},
#  {'QUERY PLAN': '                                      Buckets: 65536 (originally 4096)  Batches: 1 (originally 1)  Memory Usage: 9536kB'},
#  {'QUERY PLAN': '                                      ->  Parallel Hash Join  (cost=13954.78..22799.56 rows=894 width=149) (actual time=460.509..537.574 rows=22608 loops=2)'},
#  {'QUERY PLAN': '                                            Hash Cond: (a_p_skill.applicant_profile_id = a_p.id)'},
#  {'QUERY PLAN': '                                            ->  Hash Join  (cost=2.50..8683.11 rows=42389 width=14) (actual time=0.518..66.473 rows=36778 loops=2)'},
#  {'QUERY PLAN': '                                                  Hash Cond: (a_p_skill.skill_id = skills.id)'},
#  {'QUERY PLAN': '                                                  ->  Parallel Seq Scan on applicantprofile_skill a_p_skill  (cost=0.00..7648.03 rows=370903 width=8) (actual time=0.278..40.071 rows=445084 loops=2)'},
#  {'QUERY PLAN': '                                                  ->  Hash  (cost=2.40..2.40 rows=8 width=14) (actual time=0.214..0.215 rows=6 loops=2)'},
#  {'QUERY PLAN': '                                                        Buckets: 1024  Batches: 1  Memory Usage: 9kB'},
#  {'QUERY PLAN': '                                                        ->  Seq Scan on skills  (cost=0.00..2.40 rows=8 width=14) (actual time=0.201..0.208 rows=6 loops=2)'},
#  {'QUERY PLAN': '                                                              Filter: ((description)::text = ANY (\'{"Apache Hadoop",Spark,AWS,Docker,Kubernetes,Java,Python,SQL}\'::text[]))'},
#  {'QUERY PLAN': '                                                              Rows Removed by Filter: 64'},
#  {'QUERY PLAN': '                                            ->  Parallel Hash  (cost=13935.01..13935.01 rows=1381 width=135) (actual time=459.507..459.515 rows=35900 loops=2)'},
#  {'QUERY PLAN': '                                                  Buckets: 131072 (originally 4096)  Batches: 1 (originally 1)  Memory Usage: 14592kB'},
#  {'QUERY PLAN': '                                                  ->  Parallel Hash Join  (cost=11988.28..13935.01 rows=1381 width=135) (actual time=415.411..438.625 rows=35900 loops=2)'},
#  {'QUERY PLAN': '                                                        Hash Cond: ((a_p.user_id)::text = (application.user_id)::text)'},
#  {'QUERY PLAN': '                                                        ->  Parallel Seq Scan on applicant_profile a_p  (cost=0.00..1695.54 rows=65454 width=41) (actual time=0.005..5.201 rows=55636 loops=2)'},
#  {'QUERY PLAN': '                                                        ->  Parallel Hash  (cost=11976.05..11976.05 rows=978 width=94) (actual time=415.362..415.368 rows=35900 loops=2)'},
#  {'QUERY PLAN': '                                                              Buckets: 131072 (originally 4096)  Batches: 1 (originally 1)  Memory Usage: 11584kB'},
#  {'QUERY PLAN': '                                                              ->  Parallel Hash Join  (cost=4444.17..11976.05 rows=978 width=94) (actual time=324.860..397.993 rows=35900 loops=2)'},
#  {'QUERY PLAN': '                                                                    Hash Cond: (application.job_id = jobs.id)'},
#  {'QUERY PLAN': '                                                                    ->  Parallel Seq Scan on application  (cost=0.00..6794.50 rows=195550 width=45) (actual time=0.246..45.761 rows=234660 loops=2)'},
#  {'QUERY PLAN': '                                                                    ->  Parallel Hash  (cost=4441.24..4441.24 rows=234 width=57) (actual time=324.127..324.130 rows=8723 loops=2)'},
#  {'QUERY PLAN': '                                                                          Buckets: 32768 (originally 1024)  Batches: 1 (originally 1)  Memory Usage: 2232kB'},
#  {'QUERY PLAN': '                                                                          ->  Hash Join  (cost=2.61..4441.24 rows=234 width=57) (actual time=1.061..307.090 rows=8723 loops=2)'},
#  {'QUERY PLAN': '                                                                                Hash Cond: (jobs.levelofexperience_id = level_of_exp.id)'},
#  {'QUERY PLAN': "                                                                                Join Filter: (to_tsvector('spanish'::regconfig, (((((jobs.name)::text || ' '::text) || (profiles_type.description)::text) || ' '::text) || (level_of_exp.name)::text)) @@ '''ingenier'' & ''dat'''::tsquery)"},
#  {'QUERY PLAN': '                                                                                Rows Removed by Join Filter: 47481'},
#  {'QUERY PLAN': '                                                                                ->  Hash Join  (cost=1.36..4311.29 rows=46841 width=53) (actual time=0.250..44.126 rows=56204 loops=2)'},
#  {'QUERY PLAN': '                                                                                      Hash Cond: (jobs.profile_type_id = profiles_type.id)'},
#  {'QUERY PLAN': '                                                                                      ->  Parallel Seq Scan on job jobs  (cost=0.00..4154.41 rows=46841 width=41) (actual time=0.080..29.994 rows=56210 loops=2)'},
#  {'QUERY PLAN': '                                                                                      ->  Hash  (cost=1.16..1.16 rows=16 width=20) (actual time=0.123..0.123 rows=16 loops=2)'},
#  {'QUERY PLAN': '                                                                                            Buckets: 1024  Batches: 1  Memory Usage: 9kB'},
#  {'QUERY PLAN': '                                                                                            ->  Seq Scan on profiletype profiles_type  (cost=0.00..1.16 rows=16 width=20) (actual time=0.104..0.106 rows=16 loops=2)'},
#  {'QUERY PLAN': '                                                                                ->  Hash  (cost=1.11..1.11 rows=11 width=12) (actual time=0.104..0.105 rows=11 loops=2)'},
#  {'QUERY PLAN': '                                                                                      Buckets: 1024  Batches: 1  Memory Usage: 9kB'},
#  {'QUERY PLAN': '                                                                                      ->  Seq Scan on levelofexp level_of_exp  (cost=0.00..1.11 rows=11 width=12) (actual time=0.090..0.092 rows=11 loops=2)'},
#  {'QUERY PLAN': 'Planning Time: 31.473 ms'},
#  {'QUERY PLAN': 'Execution Time: 672.534 ms'}]

# %%
import pandas as pd

data = []
for item in aplicantes_filtrados:
    line = item['QUERY PLAN']
    if 'cost=' in line and 'actual time=' in line:
        operation = line.split('  ')[-1].strip()  # Operación
        cost = line.split('cost=')[1].split(' ')[0].split('..')
        actual_time = line.split('actual time=')[1].split(' ')[0].split('..')
        rows = line.split('rows=')[1].split(' ')[0] if 'rows=' in line else None
        data.append({
            'Operación': operation,
            'Costo Inicial': float(cost[0]),
            'Costo Final': float(cost[1]),
            'Tiempo Inicial (ms)': float(actual_time[0]),
            'Tiempo Final (ms)': float(actual_time[1]),
            'Filas Procesadas': int(rows) if rows else None
        })

# Crear un DataFrame
df = pd.DataFrame(data)

df
# Out:
#                                             Operación  Costo Inicial  \
# 0   (cost=29561.12..29869.94 rows=2145 width=200) ...       29561.12
# 1   (cost=29561.12..29805.59 rows=2145 width=178) ...       29561.12
# 2   (cost=28561.11..28564.26 rows=1262 width=178) ...       28561.11
# 3   (cost=25177.76..28496.11 rows=1262 width=178) ...       25177.76
# 4   (cost=0.00..3065.54 rows=65454 width=97) (actu...           0.00
# 5   (cost=25161.98..25161.98 rows=1262 width=89) (...       25161.98
# 6   (cost=22810.74..25161.98 rows=1262 width=89) (...       22810.74
# 7   (cost=0.00..2100.54 rows=65454 width=51) (actu...           0.00
# 8   (cost=22799.56..22799.56 rows=894 width=149) (...       22799.56
# 9   (cost=13954.78..22799.56 rows=894 width=149) (...       13954.78
# 10  (cost=2.50..8683.11 rows=42389 width=14) (actu...           2.50
# 11  (cost=0.00..7648.03 rows=370903 width=8) (actu...           0.00
# 12  (cost=2.40..2.40 rows=8 width=14) (actual time...           2.40
# 13  (cost=0.00..2.40 rows=8 width=14) (actual time...           0.00
# 14  (cost=13935.01..13935.01 rows=1381 width=135) ...       13935.01
# 15  (cost=11988.28..13935.01 rows=1381 width=135) ...       11988.28
# 16  (cost=0.00..1695.54 rows=65454 width=41) (actu...           0.00
# 17  (cost=11976.05..11976.05 rows=978 width=94) (a...       11976.05
# 18  (cost=4444.17..11976.05 rows=978 width=94) (ac...        4444.17
# 19  (cost=0.00..6794.50 rows=195550 width=45) (act...           0.00
# 20  (cost=4441.24..4441.24 rows=234 width=57) (act...        4441.24
# 21  (cost=2.61..4441.24 rows=234 width=57) (actual...           2.61
# 22  (cost=1.36..4311.29 rows=46841 width=53) (actu...           1.36
# 23  (cost=0.00..4154.41 rows=46841 width=41) (actu...           0.00
# 24  (cost=1.16..1.16 rows=16 width=20) (actual tim...           1.16
# 25  (cost=0.00..1.16 rows=16 width=20) (actual tim...           0.00
# 26  (cost=1.11..1.11 rows=11 width=12) (actual tim...           1.11
# 27  (cost=0.00..1.11 rows=11 width=12) (actual tim...           0.00
#
#     Costo Final  Tiempo Inicial (ms)  Tiempo Final (ms)  Filas Procesadas
# 0      29869.94              633.028            670.139              2145
# 1      29805.59              633.015            651.407              2145
# 2      28564.26              626.875            628.774              1262
# 3      28496.11              575.553            605.282              1262
# 4       3065.54                0.003             16.799             65454
# 5      25161.98              575.218            575.231              1262
# 6      25161.98              549.241            567.264              1262
# 7       2100.54                0.003              5.408             65454
# 8      22799.56              549.158            549.170               894
# 9      22799.56              460.509            537.574               894
# 10      8683.11                0.518             66.473             42389
# 11      7648.03                0.278             40.071            370903
# 12         2.40                0.214              0.215                 8
# 13         2.40                0.201              0.208                 8
# 14     13935.01              459.507            459.515              1381
# 15     13935.01              415.411            438.625              1381
# 16      1695.54                0.005              5.201             65454
# 17     11976.05              415.362            415.368               978
# 18     11976.05              324.860            397.993               978
# 19      6794.50                0.246             45.761            195550
# 20      4441.24              324.127            324.130               234
# 21      4441.24                1.061            307.090               234
# 22      4311.29                0.250             44.126             46841
# 23      4154.41                0.080             29.994             46841
# 24         1.16                0.123              0.123                16
# 25         1.16                0.104              0.106                16
# 26         1.11                0.104              0.105                11
# 27         1.11                0.090              0.092                11
